# %%
import pandas as pd
# from google.colab import files
# files.upload()
# Out:
#      <input type="file" id="files-1fcce6cd-c64a-452f-bbde-9c4673562e0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fcce6cd-c64a-452f-bbde-9c4673562e0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("titanic.csv")
df.head(10)
df.tail()
df.sample(10)
# df = pd.read_excel("random.xlxs")
# df = pd.read_json("url")
# Out:
#     Cabin      Ticket number  Survived
# 281   NaN      347464      A         0
# 394    G6     PP 9549      6         1
# 442   NaN      347076      6         0
# 145   NaN  C.A. 33112      A         0
# 213   NaN      250646      1         0
# 116   NaN      370369      A         0
# 302   NaN        LINE      2         0
# 106   NaN      343120      3         1
# 79    NaN      364516      A         1
# 504   B79      110152      6         1

# %%
data = {
    "name" : ["amir", "ram", "shyam", "sita", "gita", "hari", "rita", "john", "laxmi", "suman"],
    "age" : [21, 22, 23, 20, 21, 24, 22, 23, 20, 25],
    "placement" : ["yes", "no", "yes", "no", "yes", "yes", "no", "yes", "no", "yes"],
    "gender": ["male", "male", "male", "female", "female", "male", "female", "male", "female", "male"],
    "marks": [85, 70, 90, 95, 88, 78, 65, 92, 73, 89]
}
df = pd.DataFrame(data)
df.head()
df.to_csv("output.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       10 non-null     object
#  1   age        10 non-null     int64
#  2   placement  10 non-null     object
#  3   gender     10 non-null     object
#  4   marks      10 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#             age      marks
# count  10.00000  10.000000
# mean   22.10000  82.500000
# std     1.66333  10.298328
# min    20.00000  65.000000
# 25%    21.00000  74.250000
# 50%    22.00000  86.500000
# 75%    23.00000  89.750000
# max    25.00000  95.000000

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['name', 'age', 'placement', 'gender', 'marks'], dtype='object')

# %%
df[['age','name']]
# Out:
#    age   name
# 0   21   amir
# 1   22    ram
# 2   23  shyam
# 3   20   sita
# 4   21   gita
# 5   24   hari
# 6   22   rita
# 7   23   john
# 8   20  laxmi
# 9   25  suman

# %%
df.iloc[1:5,1:4]
# Out:
#    age placement  gender
# 1   22        no    male
# 2   23       yes    male
# 3   20        no  female
# 4   21       yes  female

# %%
df['result'] = ['pass','pass','pass','pass','fail','pass','pass','pass','pass','pass']
df.head()
# Out:
#     name  age placement  gender  marks result
# 0   amir   21       yes    male     85   pass
# 1    ram   22        no    male     70   pass
# 2  shyam   23       yes    male     90   pass
# 3   sita   20        no  female     95   pass
# 4   gita   21       yes  female     88   fail

# %%
df.head()
# Out:
#     name  age placement  gender  marks result
# 0   amir   21       yes    male     85   pass
# 1    ram   22        no    male     70   pass
# 2  shyam   23       yes    male     90   pass
# 3   sita   20        no  female     95   pass
# 4   gita   21       yes  female     88   fail

# %%
df['result_cal'] = df['marks'].apply(lambda x : 'pass' if x > 70 else 'fail')
df
# Out:
#     name  age placement  gender  marks result result_cal
# 0   amir   21       yes    male     85   pass       pass
# 1    ram   22        no    male     70   pass       fail
# 2  shyam   23       yes    male     90   pass       pass
# 3   sita   20        no  female     95   pass       pass
# 4   gita   21       yes  female     88   fail       pass
# 5   hari   24       yes    male     78   pass       pass
# 6   rita   22        no  female     65   pass       fail
# 7   john   23       yes    male     92   pass       pass
# 8  laxmi   20        no  female     73   pass       pass
# 9  suman   25       yes    male     89   pass       pass

# %%
df.loc[5,'name'] = "Narayan"
df
# Out:
#       name  age placement  gender  marks result result_cal
# 0     amir   21       yes    male     85   pass       pass
# 1      ram   22        no    male     70   pass       fail
# 2    shyam   23       yes    male     90   pass       pass
# 3     sita   20        no  female     95   pass       pass
# 4     gita   21       yes  female     88   fail       pass
# 5  Narayan   24       yes    male     78   pass       pass
# 6     rita   22        no  female     65   pass       fail
# 7     john   23       yes    male     92   pass       pass
# 8    laxmi   20        no  female     73   pass       pass
# 9    suman   25       yes    male     89   pass       pass

# %%
df['marks'] = df['marks'] * 100
df
# Out:
#       name  age placement  gender   marks result result_cal
# 0     amir   21       yes    male  850000   pass       pass
# 1      ram   22        no    male  700000   pass       fail
# 2    shyam   23       yes    male  900000   pass       pass
# 3     sita   20        no  female  950000   pass       pass
# 4     gita   21       yes  female  880000   fail       pass
# 5  Narayan   24       yes    male  780000   pass       pass
# 6     rita   22        no  female  650000   pass       fail
# 7     john   23       yes    male  920000   pass       pass
# 8    laxmi   20        no  female  730000   pass       pass
# 9    suman   25       yes    male  890000   pass       pass

# %%
df.drop(columns = 'result',inplace = True)
df
# Out:
#       name  age placement  gender   marks result_cal
# 0     amir   21       yes    male  850000       pass
# 1      ram   22        no    male  700000       fail
# 2    shyam   23       yes    male  900000       pass
# 3     sita   20        no  female  950000       pass
# 4     gita   21       yes  female  880000       pass
# 5  Narayan   24       yes    male  780000       pass
# 6     rita   22        no  female  650000       fail
# 7     john   23       yes    male  920000       pass
# 8    laxmi   20        no  female  730000       pass
# 9    suman   25       yes    male  890000       pass

# %%
df.sort_values(by = 'age',ascending=False,inplace = True)
df
# Out:
#       name  age placement  gender   marks result_cal
# 9    suman   25       yes    male  890000       pass
# 5  Narayan   24       yes    male  780000       pass
# 7     john   23       yes    male  920000       pass
# 2    shyam   23       yes    male  900000       pass
# 6     rita   22        no  female  650000       fail
# 1      ram   22        no    male  700000       fail
# 4     gita   21       yes  female  880000       pass
# 0     amir   21       yes    male  850000       pass
# 8    laxmi   20        no  female  730000       pass
# 3     sita   20        no  female  950000       pass

# %%
df['gender'].value_counts()
# Out:
# gender
# male      6
# female    4
# Name: count, dtype: int64

# %%
df['result_cal'].value_counts()
# Out:
# result_cal
# pass    8
# fail    2
# Name: count, dtype: int64
